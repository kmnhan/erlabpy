# %% [raw]
# Selecting and indexing data
# ===========================
#
# In most cases, the powerful data manipulation and indexing methods provided by :mod:`xarray` are sufficient. In this page, some frequently used :mod:`xarray` features are summarized in addition to some utilities provided by PyARPES. Refer to the `xarray user guide <https://docs.xarray.dev/en/stable/usedatr-guide/indexing.html>`_ for detailed documentation.
#
# First, let us import some example data: a simple tight binding simulation of graphene.

# %%
from erlab.interactive.exampledata import generate_data

dat = generate_data()

# %%
dat
# Out:
# <xarray.DataArray (kx: 250, ky: 250, eV: 300)>
# array([[[1.29636308e+03, 1.27735016e+03, 1.27944386e+03, ...,
#          1.63480306e-01, 1.47424058e-01, 1.41963740e-01],
#         [1.30331412e+03, 1.30270490e+03, 1.30982226e+03, ...,
#          3.49067495e-01, 5.16131637e-01, 2.53766126e-01],
#         [1.29569290e+03, 1.32382013e+03, 1.33022357e+03, ...,
#          4.07817332e-01, 6.71690041e-01, 5.96927023e-01],
#         ...,
#         [1.32185023e+03, 1.32639544e+03, 1.30587699e+03, ...,
#          1.15344379e+00, 8.07332075e-01, 6.93013625e-01],
#         [1.27031217e+03, 1.30806538e+03, 1.30337588e+03, ...,
#          8.12151321e-01, 4.10769828e-01, 2.83560097e-01],
#         [1.25141719e+03, 1.29455401e+03, 1.32120926e+03, ...,
#          2.76629886e-01, 4.93146432e-01, 1.43812055e-01]],
#
#        [[1.25792367e+03, 1.27021309e+03, 1.26609202e+03, ...,
#          5.00360254e-01, 3.18270860e-01, 4.88736768e-01],
#         [1.26135975e+03, 1.27967753e+03, 1.26904369e+03, ...,
#          6.26232673e-01, 2.69181713e-01, 1.47702221e-01],
#         [1.25661192e+03, 1.28132611e+03, 1.27831496e+03, ...,
#          7.09584351e-01, 2.89783081e-01, 1.32698094e-01],
# ...
#         [1.30156102e+03, 1.32050367e+03, 1.29376768e+03, ...,
#          5.83913194e-01, 3.15880355e-01, 3.00752050e-01],
#         [1.30745707e+03, 1.30251960e+03, 1.28401636e+03, ...,
#          2.20996827e-01, 5.48141809e-02, 5.27479671e-02],
#         [1.29180017e+03, 1.24922855e+03, 1.26698540e+03, ...,
#          2.87429786e-02, 2.83454183e-02, 1.15002041e-01]],
#
#        [[1.29418569e+03, 1.26719010e+03, 1.29630622e+03, ...,
#          2.32169395e-01, 5.73552192e-01, 1.39632125e-01],
#         [1.27339997e+03, 1.27674901e+03, 1.29990229e+03, ...,
#          1.81750060e-01, 4.89148763e-01, 1.23137911e-01],
#         [1.29634982e+03, 1.30428966e+03, 1.30232144e+03, ...,
#          2.29403648e-01, 2.15458178e-01, 1.56911653e-01],
#         ...,
#         [1.33556318e+03, 1.34827775e+03, 1.33137882e+03, ...,
#          5.12803717e-01, 4.07097297e-01, 8.59932875e-01],
#         [1.33883863e+03, 1.32553252e+03, 1.31388910e+03, ...,
#          1.22653258e-01, 5.40398488e-02, 1.20797311e-01],
#         [1.32980753e+03, 1.30896259e+03, 1.29603749e+03, ...,
#          3.28836423e-03, 1.21926600e-03, 3.54787741e-03]]])
# Coordinates:
#   * kx       (kx) float64 -0.85 -0.8432 -0.8363 -0.8295 ... 0.8363 0.8432 0.85
#   * ky       (ky) float64 -0.85 -0.8432 -0.8363 -0.8295 ... 0.8363 0.8432 0.85
#   * eV       (eV) float64 -0.45 -0.4482 -0.4464 -0.4446 ... 0.08639 0.08819 0.09

# %% [raw]
# We can see that the generated data is a three-dimensional :class:`xarray.DataArray` . Now, let's extract a cut along :math:`k_y = 0.3`.

# %%
dat.sel(ky=0.3, method="nearest")
# Out:
# <xarray.DataArray (kx: 250, eV: 300)>
# array([[1.29126850e+03, 1.28338743e+03, 1.25698888e+03, ...,
#         4.84844554e-01, 2.58586645e-01, 6.87341297e-01],
#        [1.29857057e+03, 1.30720075e+03, 1.31250685e+03, ...,
#         2.39762952e-01, 1.23475534e-01, 1.76153128e-01],
#        [1.33988537e+03, 1.32775270e+03, 1.34680102e+03, ...,
#         3.64624485e-01, 3.21476125e-01, 2.22591269e-01],
#        ...,
#        [1.32294087e+03, 1.31470807e+03, 1.29432831e+03, ...,
#         9.31225979e-02, 2.39969460e-01, 5.40687916e-01],
#        [1.30503991e+03, 1.28213872e+03, 1.26669571e+03, ...,
#         2.04045415e-01, 2.61200909e-01, 3.88477791e-01],
#        [1.26504496e+03, 1.25835749e+03, 1.26104870e+03, ...,
#         3.54723533e-01, 4.94433526e-01, 4.87615171e-01]])
# Coordinates:
#   * kx       (kx) float64 -0.85 -0.8432 -0.8363 -0.8295 ... 0.8363 0.8432 0.85
#     ky       float64 0.297
#   * eV       (eV) float64 -0.45 -0.4482 -0.4464 -0.4446 ... 0.08639 0.08819 0.09

# %% [markdown]
# How about the Fermi surface?

# %%
dat.sel(eV=0.0, method="nearest")
# Out:
# <xarray.DataArray (kx: 250, ky: 250)>
# array([[945.01470821, 943.27022354, 965.80390379, ..., 957.13826766,
#         967.2077956 , 945.60449258],
#        [917.82381432, 906.15926035, 923.71743727, ..., 933.49874645,
#         932.71618586, 930.6085169 ],
#        [879.75018095, 881.12804122, 892.45022763, ..., 892.35229276,
#         886.39350487, 874.03602843],
#        ...,
#        [886.05384648, 900.97782543, 902.02973866, ..., 895.72841257,
#         879.20115646, 867.62313034],
#        [928.51280017, 937.30623138, 952.91192333, ..., 948.41894703,
#         939.77013318, 905.11250743],
#        [954.74365457, 937.99741879, 957.76208785, ..., 953.76325703,
#         946.67138152, 921.2271926 ]])
# Coordinates:
#   * kx       (kx) float64 -0.85 -0.8432 -0.8363 -0.8295 ... 0.8363 0.8432 0.85
#   * ky       (ky) float64 -0.85 -0.8432 -0.8363 -0.8295 ... 0.8363 0.8432 0.85
#     eV       float64 -0.000301

# %% [markdown]
# In real experimental data,
